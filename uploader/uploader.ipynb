# %% [markdown]
# ## Setup

# %%
import os
import pathlib
from supabase import create_client, Client
from dotenv import load_dotenv

env = load_dotenv()

URL = os.getenv('SUPABASE_URL')
KEY = os.getenv('SUPABASE_SECRET_KEY')
BUCKET = "stills"
IMPORT_ROOT = pathlib.Path.cwd().joinpath("works")

DRY_RUN = False
KEEP_ORIGINAL = False

supabase: Client = create_client(supabase_url=URL or "", supabase_key=KEY or "")

# %% [markdown]
# ## Images

# %%
from scripts.files_helper import import_work_folder


work_dirs = sorted([p for p in IMPORT_ROOT.iterdir() if p.is_dir()])
for work_dir in work_dirs:
    import_work_folder(
        work_dir,
        supabase,
        BUCKET,
        dry_run=DRY_RUN,
        keep_original=KEEP_ORIGINAL,
    )
# Out:
# === Importing bozi_muka ===
#   uploaded w480: 480x375
#   uploaded w960: 960x749
#   uploaded w1600: 1330x1038
#   inserted still 1: Bozi Muka_still1.jpg -> 5a45b7db-c9a0-403f-bcbb-975758db107c
#   uploaded w480: 480x375
#   uploaded w960: 960x750
#   uploaded w1600: 1329x1038
#   inserted still 2: Bozi Muka_still2.jpg -> c82655b5-750a-4be3-88f9-a1513a7e0c30
#   uploaded w480: 480x374
#   uploaded w960: 960x747
#   uploaded w1600: 1331x1036
#   inserted still 3: Bozi Muka_still8.jpg -> 28fa932e-823a-4fc6-9e2e-e97f6396aeab
# Done: Boží Muka (f3f85ef8-5a6a-4394-a5bd-39ddfe3385c9)
#
# === Importing christian ===
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[7], line 6
#       4 work_dirs = sorted([p for p in IMPORT_ROOT.iterdir() if p.is_dir()])
#       5 for work_dir in work_dirs:
# ----> 6     import_work_folder(
#       7         work_dir,
#       8         supabase,
#       9         BUCKET,
#      10         dry_run=DRY_RUN,
#      11         keep_original=KEEP_ORIGINAL,
#      12     )
#
# File c:\Users\jrp\Codes\jrp\silent\uploader\scripts\files_helper.py:28, in import_work_folder(work_dir, client, bucket, dry_run, keep_original)
#      25 def import_work_folder(work_dir: Path, client, bucket, dry_run=False, keep_original=False):
#      26     print(f"\n=== Importing {work_dir.name} ===")
# ---> 28     meta = load_meta(work_dir)
#      30     image_paths = sorted([
#      31         p for p in work_dir.iterdir()
#      32         if p.is_file() and p.suffix.lower() in {".jpg", ".jpeg", ".png", ".webp"}
#      33     ])
#      35     if not image_paths:
#
# File c:\Users\jrp\Codes\jrp\silent\uploader\scripts\files_helper.py:13, in load_meta(work_dir)
#      11 meta_path = work_dir / "meta.json"
#      12 if not meta_path.exists():
# ---> 13     raise FileNotFoundError(f"Missing meta.json in {work_dir}")
#      15 meta = json.loads(meta_path.read_text(encoding="utf-8"))
#      17 return {
#      18     "name": meta["name"],
#      19     "description": meta.get("description"),
#    (...)     22     "video_link": meta.get("video_link"),
#      23 }
#
# FileNotFoundError: Missing meta.json in c:\Users\jrp\Codes\jrp\silent\uploader\works\christian
